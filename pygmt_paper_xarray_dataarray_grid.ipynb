# %%
import pygmt
import xarray as xr

# Download the dataset from the IRI Data Library
url = "https://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NODC/.WOA09/.Grid-1x1/.Annual/.temperature/.t_an/data.nc"
netcdf_file = pygmt.which(fname=url, download=True)
woa_temp = xr.open_dataset(netcdf_file).isel(time=0)

# Make a static plot of sea surface temperature
fig = pygmt.Figure()
fig.grdimage(
    grid=woa_temp.t_an.sel(depth=0), cmap="SCM/batlow", projection="N10c", frame=True
)
fig.colorbar(frame=["xa5+lsea surface temperature", "y+l@.C"])
fig.show(dpi=150)
# Out:
# grdinfo [WARNING]: No 3-D array in file C:\Users\Admin\C2\EigeneDokumente\Studium\Promotion\01_GitHub\github_pygmt\pygmt-paper-figures\data.nc.  Selecting first 3-D slice in the 4-D array t_an
